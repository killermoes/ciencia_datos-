# %% [markdown]
# # Curso de Introducción a la Ciencia de Datos

# %% [markdown]
# Este notebook contiene una serie de ejercicios para que practiquen programación en Python. Cada ejercicio incluye una breve descripción y una celda donde se debe escribir el código. ¡Manos a la obra!

# %% [markdown]
# ## 1. ¿Cuánto es 117 * 48?

# %%
117*48
# Out:
# 5616

# %% [markdown]
# # 2. ¿Cuánto es $7^6$?

# %%
7**6
# Out:
# 117649

# %% [markdown]
# ## 3. Divide esta cadena de caracteres y conviértela en una lista
#
# ```python
# s = "¡Hola estoy contento aprendiendo Python!"

# %%
x = "¡Hola estoy contento aprendiendo Python!"

# %%
lista = x.split()
print(lista)
# Out:
# ['¡Hola', 'estoy', 'contento', 'aprendiendo', 'Python!']

# %%
# Se espera imprimir: ['Hola', 'Estoy', 'feliz', 'aprendiendo', 'python!']

# %% [markdown]
# ## 4. Dadas las variables `municipio` y `distancia` imprima lo siguiente:
#
# ```python
# Del municipio de Sabaneta al la comuna El Poblado hay aproximadamente 6 km

# %%
municipio = "Sabaneta"

distancia = 8

# %%
# Copie su código acá

"Del municipio de " + municipio + " a Medellín hay " + str(distancia) + " kilómetros"
# Out:
# 'Del municipio de Sabaneta a Medellín hay 8 kilómetros'

# %% [markdown]
# ## 5. Dada la siguiente lista, use la indexación para extraer la palabra "felicidad"

# %%
lista = [1, 2, [3, 4, 5, [100, 200, ["felicidad"]], 23, 11], 1, 7]

# %%
# Copie su código acá
# Se espera imprimir: ['felicidad']

lista[2][3][2]
# Out:
# ['felicidad']

# %%
almacen = ["Harina", "Azúcar", ["Clavos", "Tornillos", "Tuercas"], "Sal"]

# EJERCICIO: Extrae la palabra "Tornillos"
# Tu código aquí:

almacen[2][1]
# Out:
# 'Tornillos'

# %%
mapa = [10, 20, [30, 40, [500, 600], 50], 60]

# EJERCICIO: Extrae el número 600
# Tu código aquí:
mapa[2][2][1]
# Out:
# 600

# %%
datos = ["Juan", "Pérez", [25, "Bogotá", ["Agente", "007"]], "Activo"]

# EJERCICIO: Extrae solo el número "007"
# Tu código aquí:
datos[2][2][1]
# Out:
# '007'

# %% [markdown]
# Dada esta lista, extrae lo que se te pide:
# misterio = ["a", "b", [10, 20, ["encontrado", "oculto"]], 30]
#
# Reto A: Extrae el número 20.
#
# Reto B: Extrae la palabra "oculto".
#
# Reto C: Extrae solo las primeras dos letras de la palabra "encontrado" (usando slicing [:2]).

# %%
# Tu código aquí:
misterio = ["a", "b", [10, 20, ["encontrado", "oculto"]], 30]

misterioA =misterio[2][1]
print(misterioA)
misterioB = misterio[2][2][1]
print(misterioB)
misterioC = misterio[2][2][0][:2]
print(misterioC)
# Out:
# 20
# oculto
# en

# %% [markdown]
# ## 6. ¿Cuál es la diferencia entre una Tupla y una Lista?

# %% [markdown]
# ## 7. Agregar elemento a una lista. Agregue el nombre `David` al final de la siguiente lista:

# %%
nombres = ["Pedro", "Alejandro"]

# %%
# Copie su código acá
nombres.append("David")
print(nombres)
# Out:
# ['Pedro', 'Alejandro', 'David']

# %% [markdown]
# ## 8. Cuente las ocurrencias de la letra `x` en la siguiente lista

# %%
lista = ["a", "b", "c", "x", "x", "X","x"]

# %%
# Copie su código acá
conteo1 = lista.count("x")
print(conteo1)
# Out:
# 3

# %% [markdown]
# ## 9. Convertir el siguiente texto a minúsculas

# %%
texto = "La vida es un SoPlO Y nOSotrOs SoMOS INstanTES"

# %%
# Copie su código acá
texto_min = texto.lower()
print(texto_min)
# Out:
# la vida es un soplo y nosotros somos instantes

# %%
# Copie su código acá
text_may = texto.upper()
print(text_may)
text_spm = texto.capitalize()
print(text_spm)
text_pm = texto.title()
print(text_pm)
# Out:
# LA VIDA ES UN SOPLO Y NOSOTROS SOMOS INSTANTES
# La vida es un soplo y nosotros somos instantes
# La Vida Es Un Soplo Y Nosotros Somos Instantes

# %% [markdown]
# ## 10. Reemplazar coma por punto

# %%
numero = "785497868974,125769822"

# %%
# Copie su código acá
numero_act = numero.replace(",",".")
print(numero_act)
# Out:
# 785497868974.125769822

# %% [markdown]
# ## 11. Función `domainGet`. Cree una función llamada domainGet que extraiga el dominio de un correo electrónico
#
# Por ejemplo:
# `domainGet("juan_perez@correo.com")` debería retornar 'correo.com'.

# %%
# Copie su código acá
correo = "cristhianbejaranomurillo@yopmail.com" 

def domainGet(correo):
    return correo.split("@")[1]

domainGet(correo)
# Out:
# 'yopmail.com'

# %% [markdown]
# **Ejercicio 2**
#
# Dada esta lista de correos:
# correos = ["ana@gmail.com", "pedro@outlook.es", "maria@yahoo.com"]
#
# Reto D: Crea una función llamada obtener_usuario que reciba un correo y devuelva solo el nombre antes del @.
#
# Ejemplo: Si le das "ana@gmail.com", debe devolver "ana".
#
# Reto E: Usando la lista correos, extrae el dominio del segundo elemento ("outlook.es") usando indexación y .split().

# %%
# Copie su código acá

correos = ["ana@gmail.com", "pedro@outlook.es", "maria@yahoo.com"]
# Reto D
def obtener_usuario(correos):
    return [correo.split("@")[0] for correo in correos]
obtener_usuario(correos)
# Out:
# ['ana', 'pedro', 'maria']

# %%
# Copie su código acá

#Reto E
def obtener_dominio(correos):
    return [correo.split("@")[1] for correo in correos]

obtener_dominio(correos)
# Out:
# ['gmail.com', 'outlook.es', 'yahoo.com']

# %% [markdown]
# ## 12. Función `buscar_palabra_promedio`
#
# Cree una función llamada `palabra_promedio` que retorne `True` si la palabra "promedio" (en cualquier forma de mayúsculas/minúsculas) está contenida en el string de entrada.
#
# Ejemplo:
#
# `palabra_promedio("El Promedio de la clase es de 4.3")` debería retornar `True`.

# %%
# Copie su código acá
texto1 = "El promedio de la clase es de 4.5"
texto2 = "El Promedio de la clase es de 4.5"
texto3 = "SU PROMEDIO FUE DE 2%"
texto4 = "La nota fue 5"


def palabra_promedio(texto):
     palabras_min = texto.lower()
 
     return "promedio" in palabras_min

print(palabra_promedio(texto1))
print(palabra_promedio(texto2))
print(palabra_promedio(texto3))
print(palabra_promedio(texto4))
# Out:
# True
# True
# True
# False

# %% [markdown]
# **Ejercicio 2**
#
# Crea las siguientes funciones siguiendo la lógica de palabra_promedio:
#
# Función contiene_python: Debe retornar True si la palabra "python" aparece en un texto, sin importar si está en mayúsculas o minúsculas.
#
# Función es_urgente: Debe retornar True si el texto termina con signos de exclamación !!. (Pista: puedes usar indexación negativa [-2:] o el método .endswith()).

# %%
# Copie su código acá
# Eje:1

texto1 = "Este ejercicio es fácil"
texto2 = "Todo se debe resolver con Python"
texto3 = "RESOLVER CON PYTHON ES DIVERTIDO"
texto4 = "python es un lenguaje de programación"

def contiene_python(texto):
    palabras_min = texto.lower()

    return "python" in palabras_min

print(contiene_python(texto1))
print(contiene_python(texto2))
print(contiene_python(texto3))
print(contiene_python(texto4))
print("-------------------------------")

# Eje:2

texto2_1 = "Este ejercicio! es fácil"
texto2_2 = "Todo se debe resolver con Python!!"
texto2_3 = "RESOLVER CON PYTHON ES DIVERTIDO!!."
texto2_4 = "python es un lenguaje de programación!"

def es_urgente(texto):
    return texto.endswith("!!.")

print(es_urgente(texto2_1))
print(es_urgente(texto2_2))         
print(es_urgente(texto2_3))
print(es_urgente(texto2_4))
# Out:
# False
# True
# True
# True
# -------------------------------
# False
# False
# True
# False

# %%
datos = ["ID_001", {"info": [1, 2, 3, "OBJETIVO"]}, "Final"]

# Copie su código acá

datos[1]["info"][3]
# Out:
# 'OBJETIVO'

# %% [markdown]
# ## 13. Función contar_python
#
# Cree una función llamada contar_python que cuente la cantidad de veces que aparece la palabra "python" en una cadena (ignorando mayúsculas y minúsculas).
#
# Ejemplo:
#
# `contar_python("Python es un lenguaje de programacion, Python es divertido")` debería retornar 2.

# %%
# Copie su código acá
texto = "Python es un lenguaje de programacion, Python es divertido"
tex =  "python es fácil de aprender"

def contar_python(textos):
    textos_min = textos.lower()

    return textos_min.count("python")

print(contar_python(texto))
print(contar_python(tex))
# Out:
# 2
# 1

# %% [markdown]
# ## 14. 💣 Detección de anomalías
#
# Un científico de datos necesita desarrollar una función para detectar anomalías en un conjunto de datos de valores positivos. La función `deteccion_anomalia` debe seguir estas reglas:
#
# 1. Recibe los siguientes argumentos:
#
#     * `valor (float):` El valor a evaluar.
#
#     * `valor_media (float):` La media del conjunto de datos.
#
#     * `desviacion_estandar (float):` La desviación estándar.
#
#     * `distribucion_normal (bool):` Indica si la distribución es normal.
#
# 2. Si la distribución es **normal** y el valor es mayor a **valor_media + 3 * desviacion_estandar**, la función retorna **"anormal"**.
#
# 3. Si la distribución es **normal** y el valor es menor a **valor_media - 3 * desviacion_estandar**, la función retorna **"normal"**.
#
# 4. En cualquier otro caso, retorna **"indeterminado"**.

# %%
# Copie su código acá

def deteccion_anomalia(valor, valor_media, desviacion_estandar, distribucion_normal):

   if distribucion_normal and valor > valor_media + 3 * desviacion_estandar:
       return "anormal"
   elif distribucion_normal:
       return "normal"
   else: 
      return"indeterminado"

# %%
# Ejemplos de prueba

print(deteccion_anomalia(
    valor=15.6, valor_media=9.5, desviacion_estandar=8.7, distribucion_normal=True
))  # Se espera: 'normal'

print(deteccion_anomalia(
    valor=45.4, valor_media=9.5, desviacion_estandar=8.7, distribucion_normal=True
))  # Se espera: 'anormal'

print(deteccion_anomalia(
    valor=15.6, valor_media=9.5, desviacion_estandar=8.7, distribucion_normal=False
))  # Se espera: 'indeterminado'
# Out:
# normal
# anormal
# indeterminado
