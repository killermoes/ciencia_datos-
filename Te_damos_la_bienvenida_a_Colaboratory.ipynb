# %% [markdown]
# <a href="https://colab.research.google.com/github/killermoes/ciencia_datos-/blob/main/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
